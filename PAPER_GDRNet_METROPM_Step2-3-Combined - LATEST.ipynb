# %% [markdown]
# <a href="https://colab.research.google.com/github/supriyag123/PHD_Pub/blob/main/PAPER_GDRNet_METROPM_Step2-3-Combined%20-%20LATEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import math
import plotly.graph_objects as go
import keras
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, RepeatVector, TimeDistributed, Input
from keras.models import Model
from keras import saving

import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import EarlyStopping
from keras.callbacks import Callback
import plotly
from keras import losses

import plotly.express as px # for data visualization
#from keras.utils import plot_model
#import matplotlib.pyplot as plt

#window1 = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences_WINDOW-500.npy')
#window2 = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences_WINDOW-1000.npy')
#window = np.concatenate((window1, window2), axis=0)
#train_data = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences-TRAIN.npy')
#test_data = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences-TEST.npy')


train_data = np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/multivariate_long_sequences-TRAIN-Daily-DIRECT-VAR.npy')
#test_data = np.load(r'/content/drive/MyDrive/PHD/2024/multivariate_long_sequences-TEST_hourly.npy')
window_label = np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/multivariate_long_sequences_WINDOW-Daily-DIRECT-VAR.npy')



n_seq = train_data.shape[0]
window_size = train_data.shape[1]
n_features = train_data.shape[2]


maxval = train_data.shape[0]
count_train = int(math.ceil(0.8*maxval))
x_train = train_data[:count_train]
x_test = train_data[count_train:]
#x_test = train_data[count_train:,:,:]

# Clear all previously registered custom objects
saving.get_custom_objects().clear()
# Create a custom layer
@saving.register_keras_serializable(package="MyLayers")
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def __init__(self, factor):
        super().__init__()
        self.factor = factor


    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

    def get_config(self):
        return {"factor": self.factor}

#Build the encoder
latent_dim = 5
intermediate_dim = 256


#Encoder
encoder_inputs =  layers.Input(shape=(window_size, n_features),name="encoder_input")
x = layers.LSTM(intermediate_dim, activation='tanh', name="lstm1", return_sequences=True)(encoder_inputs)
xx = layers.LSTM(int(intermediate_dim/2), activation='tanh', name="lstm2", return_sequences=False)(x)
x1 = layers.Dense(int(intermediate_dim/2), name="dense" )(xx)
z_mean = layers.Dense(latent_dim, name="z_mean")(x1)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x1)
z = Sampling(1)([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()


#Dcoder

inp_z = Input(shape=(latent_dim,),name="decoder")
x1 = layers.RepeatVector(window_size, name="repeatvect")(inp_z)
x2= layers.Dense(int(intermediate_dim/2),  name="Dense2")(x1)
x22= layers.LSTM(int(intermediate_dim/2),activation='tanh', return_sequences=True, name="lstm1")(x2)
x3 = layers.LSTM(intermediate_dim,activation='tanh', return_sequences=True, name="lstm2")(x22)
decode_out = layers.TimeDistributed(Dense(n_features), name="decodeout")(x3)
#decode_out = layers.LSTM(n_features,name='decodeout', return_sequences=True)(x2) #Alternative
decoder = keras.Model(inp_z, decode_out, name="decoder")
decoder.summary()

reduce_lr = tf.keras.callbacks.LearningRateScheduler(lambda x: 1e-3 * 0.90 ** x)


#Parameters
n_epochs = 150 # total number of epochs
klstart = 20 # The number of epochs at which KL loss should be included
kl_annealtime = n_epochs-klstart
# the starting value of weight is 0
# define it as a keras backend variable
weight = K.variable(0.0)

#Define the VAE as a Model with a custom train_step
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,

        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    losses.mean_squared_error(data, reconstruction), axis=-1),keepdims=True
                )

            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            #K.print_tensor(weight)
            total_loss = reconstruction_loss + (weight*kl_loss)
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):

            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    losses.mean_squared_error(data, reconstruction), axis=-1),keepdims=True
                )

            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))

            total_loss = reconstruction_loss + kl_loss

            return {
                "loss": self.total_loss_tracker.result(),
                "reconstruction_loss": self.reconstruction_loss_tracker.result(),
                "kl_loss": self.kl_loss_tracker.result(),
                  }



# CALLBACKS
es = keras.callbacks.EarlyStopping(patience=50, verbose=1, min_delta=0.0001, monitor='loss', mode='auto', restore_best_weights=True)

class AnnealingCallback(Callback):
    def __init__(self, weight):
        self.weight = weight
    def on_epoch_end (self, epoch, logs={}):
        if epoch > klstart and epoch <klstart*1.2:
            new_weight = min(K.get_value(self.weight) + (1./ kl_annealtime), 1.)
            K.set_value(self.weight, new_weight)
        print ("Current KL Weight is " + str(K.get_value(self.weight)))

#Train the VAE

vae = VAE(encoder, decoder)



vae.compile(optimizer=keras.optimizers.Adam(clipnorm=1))
history=vae.fit( x_train,
                 epochs=n_epochs,
                 batch_size=32,
                 validation_split=0.1,
                 #callbacks=[es,AnnealingCallback(weight),reduce_lr])
                 callbacks=[AnnealingCallback(weight)])


encoder.save(r'/content/drive/MyDrive/PHD/2024/VAE_SIMULATION/METROPM_vae-encoder-latent5-dim256.keras')
decoder.save(r'/content/drive/MyDrive/PHD/2024/VAE_SIMULATION/METROPM_vae-decoder-latent5-dim256.keras')

encoder = keras.models.load_model(r'/content/drive/MyDrive/PHD/2024/VAE_SIMULATION/METROPM_vae-encoder-latent5-dim256.keras')
decoder = keras.models.load_model(r'/content/drive/MyDrive/PHD/2024/VAE_SIMULATION/METROPM_vae-decoder-latent5-dim256.keras')



plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['reconstruction_loss'], label='reconstruction_loss')
plt.plot(history.history['kl_loss'], label='kl_Loss')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.legend(['kl_loss'], loc='upper left')
plt.legend()
plt.grid(True)
plt.ylim(0, 100)
plt.show()

#Just Loss

plt.plot(history.history['loss'], label='Training Loss')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.legend(['kl_loss'], loc='upper left')
plt.legend()
plt.grid(True)
#plt.ylim(0, 100)
plt.show()

#PLOT TRAIN RECONSTRUCTION
X_test_encoded = encoder.predict(x_train)
X_test_predict = decoder(X_test_encoded[2])
plt.suptitle('Example Reconstruction of Training Data')
plt.xlabel('Time', fontsize ='10')
plt.ylabel('Feature 6', fontsize='10')

plt.plot(x_train[:,:,5],"r", label="Actual")
plt.plot(X_test_predict[:,:,5],"b", label="reconstructed")
#plt.legend()
plt.show()

#PLOT TEST RECONSTRUCTION
X_test_encoded = encoder.predict(x_test[:,:,:])
X_test_predict = decoder(X_test_encoded[2])
plt.suptitle('Example Reconstruction of Testing Data')
plt.xlabel('Time', fontsize ='10')
plt.ylabel('Feature 6', fontsize='10')
plt.plot(x_test[:,:,5],"r")
plt.plot(X_test_predict[:,:,5],"b")
plt.show()

fig = px.scatter(None, x=X_test_encoded[2][:,0], y=X_test_encoded[2][:,1],opacity=1, color=window_label.astype(str))
fig.update_layout(dict(plot_bgcolor = 'white'))
fig.update_traces(marker=dict(size=2))
fig.show()

#--------------------------------------Trysimple encoder--------------------------------------------------------------------------------------
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import math
import plotly.graph_objects as go
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, RepeatVector, TimeDistributed, Input
from keras.models import Model
from keras import backend as K
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import EarlyStopping
import keras.backend as K
from keras.callbacks import Callback
import plotly
import plotly.express as px # for data visualization
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
import numpy as np
import scipy.stats as stats
import pylab as pl

generator_multiply = 100 #each input record will generate 100 random vectors from the latent space, given the mu and sigma generated by the encoder

#from keras.utils import plot_model
#import matplotlib.pyplot as plt

#window1 = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences_WINDOW-500.npy')
#window2 = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences_WINDOW-1000.npy')
#window = np.concatenate((window1, window2), axis=0)
#train_data = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences-TRAIN.npy')
#test_data = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences-TEST.npy')


train_data = np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/multivariate_long_sequences-TRAIN-Daily-DIRECT-VAR.npy')
#test_data = np.load(r'/content/drive/MyDrive/PHD/2024/multivariate_long_sequences-TEST_hourly.npy')
window_label = np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/multivariate_long_sequences_WINDOW-Daily-DIRECT-VAR.npy')




n_seq = train_data.shape[0]
window_size = train_data.shape[1]
n_features = train_data.shape[2]


x_train = train_data
#x_test = test_data
#x_test = train_data[count_train:,:,:]
#x_test_final = x_train
#window_label_ho = window_label_test



#----------------check window distribution - we see upto 20 has very high fequency. so we remove that and take the rest to generate more samples, to create overall uniform distribution...
#First we test window 20 to 30 and see if this method can fit the model well

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.title("Distribution before Transformation", fontsize=15)
sns.histplot(window_label, kde=True, color="red")
plt.subplot(1,2,2)



##---------------------------IGNORE THIS IF NOT GENERATING FRESH VAE DATASET--------------------------------------------------------------------------------------------

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error


encoder = keras.models.load_model(r'/content/drive/MyDrive/PHD/2024/VAE_SIMULATION/METROPM_vae-encoder-latent5-dim256.keras')
decoder = keras.models.load_model(r'/content/drive/MyDrive/PHD/2024/VAE_SIMULATION/METROPM_vae-decoder-latent5-dim256.keras')

X_train_encoded = encoder.predict(train_data)
mu, logvar, z = X_train_encoded
sigma = tf.exp(0.5 * logvar)
batch = tf.shape(mu)[0]  #number of recors / batchs
dim = tf.shape(mu)[1] #Ndimension of latent variable
store = list()
storetemp = list()


#For each batch, iterate, get the generator_multipy number of latent vectors with same window_size.
#For each z, concatenate z_mean, so it will become 100 dimensional vector

for i in range(0,batch):
  all_Z_i = tf.random.normal(shape=(generator_multiply,dim), mean = mu[i,:], stddev=sigma[i,:]) #all randorm vectors for this record i
  X_train_decoded = decoder.predict(all_Z_i)
  X_train_decoded = X_train_decoded.reshape((X_train_decoded.shape[0],window_size*n_features))
  #a = np.arange(generator_multiply)
  #a.fill(window_label[i])
  #c=np.concatenate(((X_train_decoded,a[:,None])),axis=1)
  store.append(X_train_decoded)

results1=np.concatenate(store,axis=0)
np.save(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated_large_subsquence2_data.npy',results1)


#----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

results1=np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated_large_subsquence2_data.npy')

x=results1


rmse_list = list()
min_window_list = list()
best_window_for_long_seq = list()
best_window_for_long_seq.clear()
#for i in range(2) :
x_3d = x.reshape((x.shape[0],window_size,n_features))
n_future = 1
K= window_size

cohort1 = 50000
cohort2 = 100000
cohort3 = 150000
cohort4 = 200000
cohort5 = 250000
cohort6 = 300000

best_window_for_long_seq.clear()

from statsmodels.tsa.api import VAR

#Split and process across multiple files-------------------------------------------------------------
for i in range(cohort3,cohort4) :
#for i in range(2) :
  #iterate over the entire  long sequences of multivariate time series

  rmse_list.clear()
  for k in range(2,(round(K))):
    cur_seq = x_3d[i,:,:]
    df = pd.DataFrame(cur_seq, columns=['V1','V2','V3','V4','V5','V6','V7'])
    df_train, df_test = df[0:-n_future], df[-n_future:]
    model= VAR(df_train)
    try:
      model_fitted1 = model.fit(k)
      forecast_input1 = df_train.values[-k:]
      fc1 = model_fitted1.forecast(y=forecast_input1, steps=n_future)
      df_forecast1 = pd.DataFrame(fc1, index=df.index[-n_future:], columns=df.columns)
      mse =  mean_squared_error(df_test['V1'], df_forecast1['V1'].values)
      rmse_list.append(mse)
    except:
      rmse_list.append(99999)
      print('VAR could not solve row number')
      print(i, k)

  #For this i, find minimum rmse for all sliding window, and corresponding sw size
  min_index = rmse_list.index(min(rmse_list))
  min_sw = min_index + 2
  print('i=', i,'SW =', min_sw, rmse_list)
  best_window_for_long_seq.append(min_sw)


#OUT OF ALL LOOPS NOW
#best_window_for_long_seq now contains the best multivariate window size for each of the long sequence i
print(best_window_for_long_seq)
Window = np.array(best_window_for_long_seq)
y= Window

np.save(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data-true-window2-COHORT4.npy',y)
np.save(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data2-COHORT14.npy',x)

#---------------------------------------------------------Get parts of the results and combine them --------------------------------

temp_d1 = x[0:50000,:]
temp_d2 = x[50000:100000,:]
temp_d3 = x[100000:150000,:]
temp_d4 = x[150000:200000,:]
temp_d5 = x[200000:250000,:]
temp_d6 = x[250000:300000,:]

temp_d = np.concatenate((temp_d1,temp_d2,temp_d3,temp_d4, temp_d5, temp_d6),axis=0)
                         #5,temp_d67,temp_d89,temp_d1011,temp_d1213,temp_d1415,temp_d1617, temp_d20),axis=0)

temp1 = np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data-true-window2-COHORT1.npy')
temp2 = np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data-true-window2-COHORT2.npy')
temp3 = np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data-true-window2-COHORT3.npy')
temp4 =  np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data-true-window2-COHORT4.npy')
temp5 =  np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data-true-window2-COHORT5.npy')
temp6 =  np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data-true-window2-COHORT6.npy')



temp = np.concatenate((temp1,temp2,temp3,temp4, temp5, temp6),axis=0)
                       #5,temp67,temp89,temp1011,temp1213,temp1415,temp1617,temp20),axis=0)



x=temp_d
y=temp

np.save(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data-true-window2.npy',y)
np.save(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data2.npy',x)



#--------------------------------------IF REQUIRED REMOVE outlier....however we are not doing this now.--------------------------------------------------------------------------------------------------------------------------------------
from sklearn.ensemble import IsolationForest
iso = IsolationForest(contamination=0.4)
yhat = iso.fit_predict(x)
# select all rows that are not outliers
mask = yhat != -1
x, y = x[mask, :], y[mask]


###############Scale the target and then split the data into train test----------------------------------------------------------------------------------------------------------------------------------

y = np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data-true-window2.npy')
x = np.load(r'/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/generated-data2.npy')


#Looking at the dist, we remove al y less than 20
from sklearn.preprocessing import PowerTransformer
transformer = StandardScaler()
y_transformed = transformer.fit_transform(y.reshape(-1,1)).flatten()
x_train, x_test, y_train, y_test = train_test_split(x, y_transformed, test_size = 0.1, random_state = 42)

#--------------------------------------------------------------------------------------CONSTRUCT, COMPILE, AND TRAIN THE MODEL------------------------------------------------------------------------------------------------------------------
#------------MLP------------------------------------------------------
#x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],1)
#x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],1)


import os
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
checkpoint_path = "/content/drive/MyDrive/PHD/2024/TEMP_OUTPUT_METROPM/ckp2.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)
# Create checkpoint  callback
cp_callback =ModelCheckpoint(checkpoint_path,
     monitor='loss',save_best_only=True,save_weights_only=True)


from keras.layers import LeakyReLU

neuron = 64
model = Sequential()

model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1))


optimizr = keras.optimizers.Adam(learning_rate=0.0003,clipnorm=1)
model.compile(loss='mean_squared_error', optimizer= optimizr, metrics=['mean_squared_error'])

#Initial Build
model.fit( x_train,y_train,
                 epochs=1,
                 batch_size=32)
                 callbacks=[cp_callback])

model.load_weights(checkpoint_path)


es = keras.callbacks.EarlyStopping(patience=20, verbose=1, min_delta=0.0001, monitor='loss', mode='min', restore_best_weights=True)
n_epochs = 2000

history=model.fit( x_train,y_train,
                 epochs=n_epochs,
                 batch_size=100,
                   validation_split=0.3, callbacks = [cp_callback])
                 #callbacks=[es])


#-------------------------LOSS-------------------------------------
# Plot training & validation loss values
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
#-----------------------------------------------------TRAIN EVALUATION----------------------------------------------------------------
y_train_pred_raw = model.predict(x_train)
y_train_pred = transformer.inverse_transform(y_train_pred_raw)
y_train_true = transformer.inverse_transform(y_train.reshape(-1,1)).flatten()

score_train= r2_score(y_train_true,y_train_pred)
print("r2 score is ==",score_train)

plt.plot(y_train_true[0:100], color = 'red', label = 'Real data')
plt.plot(y_train_pred[0:100], color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()


#-----------------------------------------------------TEST EVALUATION----------------------------------------------------------------

y_pred_raw = model.predict(x_test)
y_test_pred = transformer.inverse_transform(y_pred_raw)
y_test_true = transformer.inverse_transform(y_test.reshape(-1,1)).flatten()



score= r2_score(y_test_true,y_test_pred)
print("r2 score is ==",score)


plt.plot(y_test_true[100:200], color = 'red', label = 'Real data')
plt.plot(y_test_pred[100:200], color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()


#------------------------------------------------------SAVE MODEL AND RESULTS-----------------------------------------------------------------

model.save(r'/content/drive/MyDrive/PHD/2024/DGRNet-MLP-Versions/METROPM_MLP_model_Daily.keras')
# It can be used to reconstruct the model identically.

# Plot training & validation loss values
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()


#------------------------------------------------------Retrieve Model-----------------------------------------------------------------

base_model = keras.models.load_model(r'/content/drive/MyDrive/PHD/2024/DGRNet-MLP-Versions/METROPM_MLP_model_Daily.keras')


#-----------------------------------------------------TEST EVALUATION----------------------------------------------------------------

y_pred_raw = base_model.predict(x_test)
y_test_pred = transformer.inverse_transform(y_pred_raw)
y_test_true = transformer.inverse_transform(y_test.reshape(-1,1)).flatten()



score= r2_score(y_test_true,y_test_pred)
print("r2 score is ==",score)


plt.plot(y_test_true[100:200], color = 'red', label = 'Real data')
plt.plot(y_test_pred[100:200], color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()



np.savetxt(r'/content/drive/MyDrive/PHD/2024/MLPOutput/METROPM_predicted_window.csv',y_test_pred)
np.savetxt(r'/content/drive/MyDrive/PHD/2024/MLPOutput/METROPM_derived_window_label.csv',y_test_true)
np.savetxt(r'/content/drive/MyDrive/PHD/2024/MLPOutput/METROPM_test_data.csv',x_test)
# Out:
# Epoch 1/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7475 - mean_squared_error: 0.7475 - val_loss: 0.7812 - val_mean_squared_error: 0.7812
# Epoch 2/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7466 - mean_squared_error: 0.7466 - val_loss: 0.7845 - val_mean_squared_error: 0.7845
# Epoch 3/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7450 - mean_squared_error: 0.7450 - val_loss: 0.7827 - val_mean_squared_error: 0.7827
# Epoch 4/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7417 - mean_squared_error: 0.7417 - val_loss: 0.7834 - val_mean_squared_error: 0.7834
# Epoch 5/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7479 - mean_squared_error: 0.7479 - val_loss: 0.7807 - val_mean_squared_error: 0.7807
# Epoch 6/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7471 - mean_squared_error: 0.7471 - val_loss: 0.7843 - val_mean_squared_error: 0.7843
# Epoch 7/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7495 - mean_squared_error: 0.7495 - val_loss: 0.7821 - val_mean_squared_error: 0.7821
# Epoch 8/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7473 - mean_squared_error: 0.7473 - val_loss: 0.7838 - val_mean_squared_error: 0.7838
# Epoch 9/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7495 - mean_squared_error: 0.7495 - val_loss: 0.7881 - val_mean_squared_error: 0.7881
# Epoch 10/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7424 - mean_squared_error: 0.7424 - val_loss: 0.7894 - val_mean_squared_error: 0.7894
# Epoch 11/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7438 - mean_squared_error: 0.7438 - val_loss: 0.7789 - val_mean_squared_error: 0.7789
# Epoch 12/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7436 - mean_squared_error: 0.7436 - val_loss: 0.7826 - val_mean_squared_error: 0.7826
# Epoch 13/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7477 - mean_squared_error: 0.7477 - val_loss: 0.7803 - val_mean_squared_error: 0.7803
# Epoch 14/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7482 - mean_squared_error: 0.7482 - val_loss: 0.7811 - val_mean_squared_error: 0.7811
# Epoch 15/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7456 - mean_squared_error: 0.7456 - val_loss: 0.7842 - val_mean_squared_error: 0.7842
# Epoch 16/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7432 - mean_squared_error: 0.7432 - val_loss: 0.7825 - val_mean_squared_error: 0.7825
# Epoch 17/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7465 - mean_squared_error: 0.7465 - val_loss: 0.7818 - val_mean_squared_error: 0.7818
# Epoch 18/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7476 - mean_squared_error: 0.7476 - val_loss: 0.7786 - val_mean_squared_error: 0.7786
# Epoch 19/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7449 - mean_squared_error: 0.7449 - val_loss: 0.7791 - val_mean_squared_error: 0.7791
# Epoch 20/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7457 - mean_squared_error: 0.7457 - val_loss: 0.7875 - val_mean_squared_error: 0.7875
# Epoch 21/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7433 - mean_squared_error: 0.7433 - val_loss: 0.7855 - val_mean_squared_error: 0.7855
# Epoch 22/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7428 - mean_squared_error: 0.7428 - val_loss: 0.7796 - val_mean_squared_error: 0.7796
# Epoch 23/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7441 - mean_squared_error: 0.7441 - val_loss: 0.7851 - val_mean_squared_error: 0.7851
# Epoch 24/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7441 - mean_squared_error: 0.7441 - val_loss: 0.7870 - val_mean_squared_error: 0.7870
# Epoch 25/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7418 - mean_squared_error: 0.7418 - val_loss: 0.7878 - val_mean_squared_error: 0.7878
# Epoch 26/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7453 - mean_squared_error: 0.7453 - val_loss: 0.7796 - val_mean_squared_error: 0.7796
# Epoch 27/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7464 - mean_squared_error: 0.7464 - val_loss: 0.7786 - val_mean_squared_error: 0.7786
# Epoch 28/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7469 - mean_squared_error: 0.7469 - val_loss: 0.7851 - val_mean_squared_error: 0.7851
# Epoch 29/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7455 - mean_squared_error: 0.7455 - val_loss: 0.7843 - val_mean_squared_error: 0.7843
# Epoch 30/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7486 - mean_squared_error: 0.7486 - val_loss: 0.7805 - val_mean_squared_error: 0.7805
# Epoch 31/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7446 - mean_squared_error: 0.7446 - val_loss: 0.7878 - val_mean_squared_error: 0.7878
# Epoch 32/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7471 - mean_squared_error: 0.7471 - val_loss: 0.7815 - val_mean_squared_error: 0.7815
# Epoch 33/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7476 - mean_squared_error: 0.7476 - val_loss: 0.7831 - val_mean_squared_error: 0.7831
# Epoch 34/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7461 - mean_squared_error: 0.7461 - val_loss: 0.7779 - val_mean_squared_error: 0.7779
# Epoch 35/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7421 - mean_squared_error: 0.7421 - val_loss: 0.7781 - val_mean_squared_error: 0.7781
# Epoch 36/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7420 - mean_squared_error: 0.7420 - val_loss: 0.7849 - val_mean_squared_error: 0.7849
# Epoch 37/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7474 - mean_squared_error: 0.7474 - val_loss: 0.7805 - val_mean_squared_error: 0.7805
# Epoch 38/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7421 - mean_squared_error: 0.7421 - val_loss: 0.7893 - val_mean_squared_error: 0.7893
# Epoch 39/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7492 - mean_squared_error: 0.7492 - val_loss: 0.7808 - val_mean_squared_error: 0.7808
# Epoch 40/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7442 - mean_squared_error: 0.7442 - val_loss: 0.7784 - val_mean_squared_error: 0.7784
# Epoch 41/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7477 - mean_squared_error: 0.7477 - val_loss: 0.7838 - val_mean_squared_error: 0.7838
# Epoch 42/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7430 - mean_squared_error: 0.7430 - val_loss: 0.7848 - val_mean_squared_error: 0.7848
# Epoch 43/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7471 - mean_squared_error: 0.7471 - val_loss: 0.7857 - val_mean_squared_error: 0.7857
# Epoch 44/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7479 - mean_squared_error: 0.7479 - val_loss: 0.7846 - val_mean_squared_error: 0.7846
# Epoch 45/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7490 - mean_squared_error: 0.7490 - val_loss: 0.7806 - val_mean_squared_error: 0.7806
# Epoch 46/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7389 - mean_squared_error: 0.7389 - val_loss: 0.7838 - val_mean_squared_error: 0.7838
# Epoch 47/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7446 - mean_squared_error: 0.7446 - val_loss: 0.7835 - val_mean_squared_error: 0.7835
# Epoch 48/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7446 - mean_squared_error: 0.7446 - val_loss: 0.7844 - val_mean_squared_error: 0.7844
# Epoch 49/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7417 - mean_squared_error: 0.7417 - val_loss: 0.7800 - val_mean_squared_error: 0.7800
# Epoch 50/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7435 - mean_squared_error: 0.7435 - val_loss: 0.7799 - val_mean_squared_error: 0.7799
# Epoch 51/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7467 - mean_squared_error: 0.7467 - val_loss: 0.7839 - val_mean_squared_error: 0.7839
# Epoch 52/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7463 - mean_squared_error: 0.7463 - val_loss: 0.7767 - val_mean_squared_error: 0.7767
# Epoch 53/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7477 - mean_squared_error: 0.7477 - val_loss: 0.7814 - val_mean_squared_error: 0.7814
# Epoch 54/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7446 - mean_squared_error: 0.7446 - val_loss: 0.7805 - val_mean_squared_error: 0.7805
# Epoch 55/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7428 - mean_squared_error: 0.7428 - val_loss: 0.7842 - val_mean_squared_error: 0.7842
# Epoch 56/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7459 - mean_squared_error: 0.7459 - val_loss: 0.7777 - val_mean_squared_error: 0.7777
# Epoch 57/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7433 - mean_squared_error: 0.7433 - val_loss: 0.7833 - val_mean_squared_error: 0.7833
# Epoch 58/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7460 - mean_squared_error: 0.7460 - val_loss: 0.7877 - val_mean_squared_error: 0.7877
# Epoch 59/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7446 - mean_squared_error: 0.7446 - val_loss: 0.7848 - val_mean_squared_error: 0.7848
# Epoch 60/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7487 - mean_squared_error: 0.7487 - val_loss: 0.7789 - val_mean_squared_error: 0.7789
# Epoch 61/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7411 - mean_squared_error: 0.7411 - val_loss: 0.7798 - val_mean_squared_error: 0.7798
# Epoch 62/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7466 - mean_squared_error: 0.7466 - val_loss: 0.7875 - val_mean_squared_error: 0.7875
# Epoch 63/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7495 - mean_squared_error: 0.7495 - val_loss: 0.7941 - val_mean_squared_error: 0.7941
# Epoch 64/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7449 - mean_squared_error: 0.7449 - val_loss: 0.7845 - val_mean_squared_error: 0.7845
# Epoch 65/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7444 - mean_squared_error: 0.7444 - val_loss: 0.7861 - val_mean_squared_error: 0.7861
# Epoch 66/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7418 - mean_squared_error: 0.7418 - val_loss: 0.7868 - val_mean_squared_error: 0.7868
# Epoch 67/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7462 - mean_squared_error: 0.7462 - val_loss: 0.7846 - val_mean_squared_error: 0.7846
# Epoch 68/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7470 - mean_squared_error: 0.7470 - val_loss: 0.7791 - val_mean_squared_error: 0.7791
# Epoch 69/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7422 - mean_squared_error: 0.7422 - val_loss: 0.7794 - val_mean_squared_error: 0.7794
# Epoch 70/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7435 - mean_squared_error: 0.7435 - val_loss: 0.7805 - val_mean_squared_error: 0.7805
# Epoch 71/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7421 - mean_squared_error: 0.7421 - val_loss: 0.7814 - val_mean_squared_error: 0.7814
# Epoch 72/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7457 - mean_squared_error: 0.7457 - val_loss: 0.7818 - val_mean_squared_error: 0.7818
# Epoch 73/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7409 - mean_squared_error: 0.7409 - val_loss: 0.7831 - val_mean_squared_error: 0.7831
# Epoch 74/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7448 - mean_squared_error: 0.7448 - val_loss: 0.7823 - val_mean_squared_error: 0.7823
# Epoch 75/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7444 - mean_squared_error: 0.7444 - val_loss: 0.7821 - val_mean_squared_error: 0.7821
# Epoch 76/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7439 - mean_squared_error: 0.7439 - val_loss: 0.7858 - val_mean_squared_error: 0.7858
# Epoch 77/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7465 - mean_squared_error: 0.7465 - val_loss: 0.7800 - val_mean_squared_error: 0.7800
# Epoch 78/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7429 - mean_squared_error: 0.7429 - val_loss: 0.7805 - val_mean_squared_error: 0.7805
# Epoch 79/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7396 - mean_squared_error: 0.7396 - val_loss: 0.7903 - val_mean_squared_error: 0.7903
# Epoch 80/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7471 - mean_squared_error: 0.7471 - val_loss: 0.7806 - val_mean_squared_error: 0.7806
# Epoch 81/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7423 - mean_squared_error: 0.7423 - val_loss: 0.7767 - val_mean_squared_error: 0.7767
# Epoch 82/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7476 - mean_squared_error: 0.7476 - val_loss: 0.7868 - val_mean_squared_error: 0.7868
# Epoch 83/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7432 - mean_squared_error: 0.7432 - val_loss: 0.7844 - val_mean_squared_error: 0.7844
# Epoch 84/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7448 - mean_squared_error: 0.7448 - val_loss: 0.7830 - val_mean_squared_error: 0.7830
# Epoch 85/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7461 - mean_squared_error: 0.7461 - val_loss: 0.7804 - val_mean_squared_error: 0.7804
# Epoch 86/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7431 - mean_squared_error: 0.7431 - val_loss: 0.7818 - val_mean_squared_error: 0.7818
# Epoch 87/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7439 - mean_squared_error: 0.7439 - val_loss: 0.7808 - val_mean_squared_error: 0.7808
# Epoch 88/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7414 - mean_squared_error: 0.7414 - val_loss: 0.7810 - val_mean_squared_error: 0.7810
# Epoch 89/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7444 - mean_squared_error: 0.7444 - val_loss: 0.7856 - val_mean_squared_error: 0.7856
# Epoch 90/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7506 - mean_squared_error: 0.7506 - val_loss: 0.7848 - val_mean_squared_error: 0.7848
# Epoch 91/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7465 - mean_squared_error: 0.7465 - val_loss: 0.7829 - val_mean_squared_error: 0.7829
# Epoch 92/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7443 - mean_squared_error: 0.7443 - val_loss: 0.7845 - val_mean_squared_error: 0.7845
# Epoch 93/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7461 - mean_squared_error: 0.7461 - val_loss: 0.7791 - val_mean_squared_error: 0.7791
# Epoch 94/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7436 - mean_squared_error: 0.7436 - val_loss: 0.7804 - val_mean_squared_error: 0.7804
# Epoch 95/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7462 - mean_squared_error: 0.7462 - val_loss: 0.7820 - val_mean_squared_error: 0.7820
# Epoch 96/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7468 - mean_squared_error: 0.7468 - val_loss: 0.7832 - val_mean_squared_error: 0.7832
# Epoch 97/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7449 - mean_squared_error: 0.7449 - val_loss: 0.7902 - val_mean_squared_error: 0.7902
# Epoch 98/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7417 - mean_squared_error: 0.7417 - val_loss: 0.7791 - val_mean_squared_error: 0.7791
# Epoch 99/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7458 - mean_squared_error: 0.7458 - val_loss: 0.7843 - val_mean_squared_error: 0.7843
# Epoch 100/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7439 - mean_squared_error: 0.7439 - val_loss: 0.7849 - val_mean_squared_error: 0.7849
# Epoch 101/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7453 - mean_squared_error: 0.7453 - val_loss: 0.7808 - val_mean_squared_error: 0.7808
# Epoch 102/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7462 - mean_squared_error: 0.7462 - val_loss: 0.7780 - val_mean_squared_error: 0.7780
# Epoch 103/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7460 - mean_squared_error: 0.7460 - val_loss: 0.7786 - val_mean_squared_error: 0.7786
# Epoch 104/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7439 - mean_squared_error: 0.7439 - val_loss: 0.7777 - val_mean_squared_error: 0.7777
# Epoch 105/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7430 - mean_squared_error: 0.7430 - val_loss: 0.7834 - val_mean_squared_error: 0.7834
# Epoch 106/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7458 - mean_squared_error: 0.7458 - val_loss: 0.7859 - val_mean_squared_error: 0.7859
# Epoch 107/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7475 - mean_squared_error: 0.7475 - val_loss: 0.7793 - val_mean_squared_error: 0.7793
# Epoch 108/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7428 - mean_squared_error: 0.7428 - val_loss: 0.7893 - val_mean_squared_error: 0.7893
# Epoch 109/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7470 - mean_squared_error: 0.7470 - val_loss: 0.7842 - val_mean_squared_error: 0.7842
# Epoch 110/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7437 - mean_squared_error: 0.7437 - val_loss: 0.7835 - val_mean_squared_error: 0.7835
# Epoch 111/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7466 - mean_squared_error: 0.7466 - val_loss: 0.7870 - val_mean_squared_error: 0.7870
# Epoch 112/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7479 - mean_squared_error: 0.7479 - val_loss: 0.7800 - val_mean_squared_error: 0.7800
# Epoch 113/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7438 - mean_squared_error: 0.7438 - val_loss: 0.7822 - val_mean_squared_error: 0.7822
# Epoch 114/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7453 - mean_squared_error: 0.7453 - val_loss: 0.7860 - val_mean_squared_error: 0.7860
# Epoch 115/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7443 - mean_squared_error: 0.7443 - val_loss: 0.7784 - val_mean_squared_error: 0.7784
# Epoch 116/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7435 - mean_squared_error: 0.7435 - val_loss: 0.7949 - val_mean_squared_error: 0.7949
# Epoch 117/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7457 - mean_squared_error: 0.7457 - val_loss: 0.7834 - val_mean_squared_error: 0.7834
# Epoch 118/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7448 - mean_squared_error: 0.7448 - val_loss: 0.7803 - val_mean_squared_error: 0.7803
# Epoch 119/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7440 - mean_squared_error: 0.7440 - val_loss: 0.7825 - val_mean_squared_error: 0.7825
# Epoch 120/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7497 - mean_squared_error: 0.7497 - val_loss: 0.7808 - val_mean_squared_error: 0.7808
# Epoch 121/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7460 - mean_squared_error: 0.7460 - val_loss: 0.7818 - val_mean_squared_error: 0.7818
# Epoch 122/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7448 - mean_squared_error: 0.7448 - val_loss: 0.7895 - val_mean_squared_error: 0.7895
# Epoch 123/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7440 - mean_squared_error: 0.7440 - val_loss: 0.7815 - val_mean_squared_error: 0.7815
# Epoch 124/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7462 - mean_squared_error: 0.7462 - val_loss: 0.7870 - val_mean_squared_error: 0.7870
# Epoch 125/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7453 - mean_squared_error: 0.7453 - val_loss: 0.7773 - val_mean_squared_error: 0.7773
# Epoch 126/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7451 - mean_squared_error: 0.7451 - val_loss: 0.7864 - val_mean_squared_error: 0.7864
# Epoch 127/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7429 - mean_squared_error: 0.7429 - val_loss: 0.7834 - val_mean_squared_error: 0.7834
# Epoch 128/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7418 - mean_squared_error: 0.7418 - val_loss: 0.7828 - val_mean_squared_error: 0.7828
# Epoch 129/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7417 - mean_squared_error: 0.7417 - val_loss: 0.7820 - val_mean_squared_error: 0.7820
# Epoch 130/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7459 - mean_squared_error: 0.7459 - val_loss: 0.7800 - val_mean_squared_error: 0.7800
# Epoch 131/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7456 - mean_squared_error: 0.7456 - val_loss: 0.7812 - val_mean_squared_error: 0.7812
# Epoch 132/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7467 - mean_squared_error: 0.7467 - val_loss: 0.7762 - val_mean_squared_error: 0.7762
# Epoch 133/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7437 - mean_squared_error: 0.7437 - val_loss: 0.7774 - val_mean_squared_error: 0.7774
# Epoch 134/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7422 - mean_squared_error: 0.7422 - val_loss: 0.7800 - val_mean_squared_error: 0.7800
# Epoch 135/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7432 - mean_squared_error: 0.7432 - val_loss: 0.7816 - val_mean_squared_error: 0.7816
# Epoch 136/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7457 - mean_squared_error: 0.7457 - val_loss: 0.7806 - val_mean_squared_error: 0.7806
# Epoch 137/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7420 - mean_squared_error: 0.7420 - val_loss: 0.7917 - val_mean_squared_error: 0.7917
# Epoch 138/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7486 - mean_squared_error: 0.7486 - val_loss: 0.7819 - val_mean_squared_error: 0.7819
# Epoch 139/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7455 - mean_squared_error: 0.7455 - val_loss: 0.7827 - val_mean_squared_error: 0.7827
# Epoch 140/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7484 - mean_squared_error: 0.7484 - val_loss: 0.7820 - val_mean_squared_error: 0.7820
# Epoch 141/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7427 - mean_squared_error: 0.7427 - val_loss: 0.7847 - val_mean_squared_error: 0.7847
# Epoch 142/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7464 - mean_squared_error: 0.7464 - val_loss: 0.7797 - val_mean_squared_error: 0.7797
# Epoch 143/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7439 - mean_squared_error: 0.7439 - val_loss: 0.7843 - val_mean_squared_error: 0.7843
# Epoch 144/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7461 - mean_squared_error: 0.7461 - val_loss: 0.7842 - val_mean_squared_error: 0.7842
# Epoch 145/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7462 - mean_squared_error: 0.7462 - val_loss: 0.7796 - val_mean_squared_error: 0.7796
# Epoch 146/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7451 - mean_squared_error: 0.7451 - val_loss: 0.7852 - val_mean_squared_error: 0.7852
# Epoch 147/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7437 - mean_squared_error: 0.7437 - val_loss: 0.7874 - val_mean_squared_error: 0.7874
# Epoch 148/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7499 - mean_squared_error: 0.7499 - val_loss: 0.7847 - val_mean_squared_error: 0.7847
# Epoch 149/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7460 - mean_squared_error: 0.7460 - val_loss: 0.7854 - val_mean_squared_error: 0.7854
# Epoch 150/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7455 - mean_squared_error: 0.7455 - val_loss: 0.7838 - val_mean_squared_error: 0.7838
# Epoch 151/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7486 - mean_squared_error: 0.7486 - val_loss: 0.7790 - val_mean_squared_error: 0.7790
# Epoch 152/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7416 - mean_squared_error: 0.7416 - val_loss: 0.7804 - val_mean_squared_error: 0.7804
# Epoch 153/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7406 - mean_squared_error: 0.7406 - val_loss: 0.7817 - val_mean_squared_error: 0.7817
# Epoch 154/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7475 - mean_squared_error: 0.7475 - val_loss: 0.7841 - val_mean_squared_error: 0.7841
# Epoch 155/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7417 - mean_squared_error: 0.7417 - val_loss: 0.7780 - val_mean_squared_error: 0.7780
# Epoch 156/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7447 - mean_squared_error: 0.7447 - val_loss: 0.7844 - val_mean_squared_error: 0.7844
# Epoch 157/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7472 - mean_squared_error: 0.7472 - val_loss: 0.7853 - val_mean_squared_error: 0.7853
# Epoch 158/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7452 - mean_squared_error: 0.7452 - val_loss: 0.7864 - val_mean_squared_error: 0.7864
# Epoch 159/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7436 - mean_squared_error: 0.7436 - val_loss: 0.7847 - val_mean_squared_error: 0.7847
# Epoch 160/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7451 - mean_squared_error: 0.7451 - val_loss: 0.7775 - val_mean_squared_error: 0.7775
# Epoch 161/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7412 - mean_squared_error: 0.7412 - val_loss: 0.7781 - val_mean_squared_error: 0.7781
# Epoch 162/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7417 - mean_squared_error: 0.7417 - val_loss: 0.7786 - val_mean_squared_error: 0.7786
# Epoch 163/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7431 - mean_squared_error: 0.7431 - val_loss: 0.7779 - val_mean_squared_error: 0.7779
# Epoch 164/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7471 - mean_squared_error: 0.7471 - val_loss: 0.7826 - val_mean_squared_error: 0.7826
# Epoch 165/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7437 - mean_squared_error: 0.7437 - val_loss: 0.7819 - val_mean_squared_error: 0.7819
# Epoch 166/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7463 - mean_squared_error: 0.7463 - val_loss: 0.7817 - val_mean_squared_error: 0.7817
# Epoch 167/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7431 - mean_squared_error: 0.7431 - val_loss: 0.7811 - val_mean_squared_error: 0.7811
# Epoch 168/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7455 - mean_squared_error: 0.7455 - val_loss: 0.7843 - val_mean_squared_error: 0.7843
# Epoch 169/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7421 - mean_squared_error: 0.7421 - val_loss: 0.7832 - val_mean_squared_error: 0.7832
# Epoch 170/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7478 - mean_squared_error: 0.7478 - val_loss: 0.7776 - val_mean_squared_error: 0.7776
# Epoch 171/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7448 - mean_squared_error: 0.7448 - val_loss: 0.7778 - val_mean_squared_error: 0.7778
# Epoch 172/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7444 - mean_squared_error: 0.7444 - val_loss: 0.7911 - val_mean_squared_error: 0.7911
# Epoch 173/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7423 - mean_squared_error: 0.7423 - val_loss: 0.7894 - val_mean_squared_error: 0.7894
# Epoch 174/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7468 - mean_squared_error: 0.7468 - val_loss: 0.7827 - val_mean_squared_error: 0.7827
# Epoch 175/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7447 - mean_squared_error: 0.7447 - val_loss: 0.7809 - val_mean_squared_error: 0.7809
# Epoch 176/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7429 - mean_squared_error: 0.7429 - val_loss: 0.7824 - val_mean_squared_error: 0.7824
# Epoch 177/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7480 - mean_squared_error: 0.7480 - val_loss: 0.7788 - val_mean_squared_error: 0.7788
# Epoch 178/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7477 - mean_squared_error: 0.7477 - val_loss: 0.7823 - val_mean_squared_error: 0.7823
# Epoch 179/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7481 - mean_squared_error: 0.7481 - val_loss: 0.7826 - val_mean_squared_error: 0.7826
# Epoch 180/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7466 - mean_squared_error: 0.7466 - val_loss: 0.7881 - val_mean_squared_error: 0.7881
# Epoch 181/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7464 - mean_squared_error: 0.7464 - val_loss: 0.7796 - val_mean_squared_error: 0.7796
# Epoch 182/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7448 - mean_squared_error: 0.7448 - val_loss: 0.7798 - val_mean_squared_error: 0.7798
# Epoch 183/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7455 - mean_squared_error: 0.7455 - val_loss: 0.7798 - val_mean_squared_error: 0.7798
# Epoch 184/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7474 - mean_squared_error: 0.7474 - val_loss: 0.7821 - val_mean_squared_error: 0.7821
# Epoch 185/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7442 - mean_squared_error: 0.7442 - val_loss: 0.7770 - val_mean_squared_error: 0.7770
# Epoch 186/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7430 - mean_squared_error: 0.7430 - val_loss: 0.7851 - val_mean_squared_error: 0.7851
# Epoch 187/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7459 - mean_squared_error: 0.7459 - val_loss: 0.7851 - val_mean_squared_error: 0.7851
# Epoch 188/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7463 - mean_squared_error: 0.7463 - val_loss: 0.7801 - val_mean_squared_error: 0.7801
# Epoch 189/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7477 - mean_squared_error: 0.7477 - val_loss: 0.7857 - val_mean_squared_error: 0.7857
# Epoch 190/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7450 - mean_squared_error: 0.7450 - val_loss: 0.7811 - val_mean_squared_error: 0.7811
# Epoch 191/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7438 - mean_squared_error: 0.7438 - val_loss: 0.7863 - val_mean_squared_error: 0.7863
# Epoch 192/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7432 - mean_squared_error: 0.7432 - val_loss: 0.7890 - val_mean_squared_error: 0.7890
# Epoch 193/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7452 - mean_squared_error: 0.7452 - val_loss: 0.7798 - val_mean_squared_error: 0.7798
# Epoch 194/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7463 - mean_squared_error: 0.7463 - val_loss: 0.7829 - val_mean_squared_error: 0.7829
# Epoch 195/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7460 - mean_squared_error: 0.7460 - val_loss: 0.7858 - val_mean_squared_error: 0.7858
# Epoch 196/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7445 - mean_squared_error: 0.7445 - val_loss: 0.7805 - val_mean_squared_error: 0.7805
# Epoch 197/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7437 - mean_squared_error: 0.7437 - val_loss: 0.7810 - val_mean_squared_error: 0.7810
# Epoch 198/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7440 - mean_squared_error: 0.7440 - val_loss: 0.7778 - val_mean_squared_error: 0.7778
# Epoch 199/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7418 - mean_squared_error: 0.7418 - val_loss: 0.7817 - val_mean_squared_error: 0.7817
# Epoch 200/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7428 - mean_squared_error: 0.7428 - val_loss: 0.7768 - val_mean_squared_error: 0.7768
# Epoch 201/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7389 - mean_squared_error: 0.7389 - val_loss: 0.7832 - val_mean_squared_error: 0.7832
# Epoch 202/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7436 - mean_squared_error: 0.7436 - val_loss: 0.7795 - val_mean_squared_error: 0.7795
# Epoch 203/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7418 - mean_squared_error: 0.7418 - val_loss: 0.7770 - val_mean_squared_error: 0.7770
# Epoch 204/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7421 - mean_squared_error: 0.7421 - val_loss: 0.7775 - val_mean_squared_error: 0.7775
# Epoch 205/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7441 - mean_squared_error: 0.7441 - val_loss: 0.7781 - val_mean_squared_error: 0.7781
# Epoch 206/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7446 - mean_squared_error: 0.7446 - val_loss: 0.7848 - val_mean_squared_error: 0.7848
# Epoch 207/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7441 - mean_squared_error: 0.7441 - val_loss: 0.7795 - val_mean_squared_error: 0.7795
# Epoch 208/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7438 - mean_squared_error: 0.7438 - val_loss: 0.7848 - val_mean_squared_error: 0.7848
# Epoch 209/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7481 - mean_squared_error: 0.7481 - val_loss: 0.7839 - val_mean_squared_error: 0.7839
# Epoch 210/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7451 - mean_squared_error: 0.7451 - val_loss: 0.7818 - val_mean_squared_error: 0.7818
# Epoch 211/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7438 - mean_squared_error: 0.7438 - val_loss: 0.7801 - val_mean_squared_error: 0.7801
# Epoch 212/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7453 - mean_squared_error: 0.7453 - val_loss: 0.7827 - val_mean_squared_error: 0.7827
# Epoch 213/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7441 - mean_squared_error: 0.7441 - val_loss: 0.7825 - val_mean_squared_error: 0.7825
# Epoch 214/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7439 - mean_squared_error: 0.7439 - val_loss: 0.7781 - val_mean_squared_error: 0.7781
# Epoch 215/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7443 - mean_squared_error: 0.7443 - val_loss: 0.7794 - val_mean_squared_error: 0.7794
# Epoch 216/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7433 - mean_squared_error: 0.7433 - val_loss: 0.7830 - val_mean_squared_error: 0.7830
# Epoch 217/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7424 - mean_squared_error: 0.7424 - val_loss: 0.7793 - val_mean_squared_error: 0.7793
# Epoch 218/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7413 - mean_squared_error: 0.7413 - val_loss: 0.7798 - val_mean_squared_error: 0.7798
# Epoch 219/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7437 - mean_squared_error: 0.7437 - val_loss: 0.7794 - val_mean_squared_error: 0.7794
# Epoch 220/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7466 - mean_squared_error: 0.7466 - val_loss: 0.7815 - val_mean_squared_error: 0.7815
# Epoch 221/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7442 - mean_squared_error: 0.7442 - val_loss: 0.7810 - val_mean_squared_error: 0.7810
# Epoch 222/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7448 - mean_squared_error: 0.7448 - val_loss: 0.7821 - val_mean_squared_error: 0.7821
# Epoch 223/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7472 - mean_squared_error: 0.7472 - val_loss: 0.7802 - val_mean_squared_error: 0.7802
# Epoch 224/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7445 - mean_squared_error: 0.7445 - val_loss: 0.7811 - val_mean_squared_error: 0.7811
# Epoch 225/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7442 - mean_squared_error: 0.7442 - val_loss: 0.7802 - val_mean_squared_error: 0.7802
# Epoch 226/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7413 - mean_squared_error: 0.7413 - val_loss: 0.7816 - val_mean_squared_error: 0.7816
# Epoch 227/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7426 - mean_squared_error: 0.7426 - val_loss: 0.7779 - val_mean_squared_error: 0.7779
# Epoch 228/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7480 - mean_squared_error: 0.7480 - val_loss: 0.7804 - val_mean_squared_error: 0.7804
# Epoch 229/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7453 - mean_squared_error: 0.7453 - val_loss: 0.7844 - val_mean_squared_error: 0.7844
# Epoch 230/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7441 - mean_squared_error: 0.7441 - val_loss: 0.7798 - val_mean_squared_error: 0.7798
# Epoch 231/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7435 - mean_squared_error: 0.7435 - val_loss: 0.7793 - val_mean_squared_error: 0.7793
# Epoch 232/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7463 - mean_squared_error: 0.7463 - val_loss: 0.7784 - val_mean_squared_error: 0.7784
# Epoch 233/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7466 - mean_squared_error: 0.7466 - val_loss: 0.7840 - val_mean_squared_error: 0.7840
# Epoch 234/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7418 - mean_squared_error: 0.7418 - val_loss: 0.7779 - val_mean_squared_error: 0.7779
# Epoch 235/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7460 - mean_squared_error: 0.7460 - val_loss: 0.7808 - val_mean_squared_error: 0.7808
# Epoch 236/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7435 - mean_squared_error: 0.7435 - val_loss: 0.7845 - val_mean_squared_error: 0.7845
# Epoch 237/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7431 - mean_squared_error: 0.7431 - val_loss: 0.7806 - val_mean_squared_error: 0.7806
# Epoch 238/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7419 - mean_squared_error: 0.7419 - val_loss: 0.7810 - val_mean_squared_error: 0.7810
# Epoch 239/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7422 - mean_squared_error: 0.7422 - val_loss: 0.7871 - val_mean_squared_error: 0.7871
# Epoch 240/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7463 - mean_squared_error: 0.7463 - val_loss: 0.7868 - val_mean_squared_error: 0.7868
# Epoch 241/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7444 - mean_squared_error: 0.7444 - val_loss: 0.7823 - val_mean_squared_error: 0.7823
# Epoch 242/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7444 - mean_squared_error: 0.7444 - val_loss: 0.7799 - val_mean_squared_error: 0.7799
# Epoch 243/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7454 - mean_squared_error: 0.7454 - val_loss: 0.7849 - val_mean_squared_error: 0.7849
# Epoch 244/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7450 - mean_squared_error: 0.7450 - val_loss: 0.7782 - val_mean_squared_error: 0.7782
# Epoch 245/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7475 - mean_squared_error: 0.7475 - val_loss: 0.7881 - val_mean_squared_error: 0.7881
# Epoch 246/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7479 - mean_squared_error: 0.7479 - val_loss: 0.7823 - val_mean_squared_error: 0.7823
# Epoch 247/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7466 - mean_squared_error: 0.7466 - val_loss: 0.7801 - val_mean_squared_error: 0.7801
# Epoch 248/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7451 - mean_squared_error: 0.7451 - val_loss: 0.7818 - val_mean_squared_error: 0.7818
# Epoch 249/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7428 - mean_squared_error: 0.7428 - val_loss: 0.7788 - val_mean_squared_error: 0.7788
# Epoch 250/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7424 - mean_squared_error: 0.7424 - val_loss: 0.7812 - val_mean_squared_error: 0.7812
# Epoch 251/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7435 - mean_squared_error: 0.7435 - val_loss: 0.7779 - val_mean_squared_error: 0.7779
# Epoch 252/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7418 - mean_squared_error: 0.7418 - val_loss: 0.7837 - val_mean_squared_error: 0.7837
# Epoch 253/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7425 - mean_squared_error: 0.7425 - val_loss: 0.7808 - val_mean_squared_error: 0.7808
# Epoch 254/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7447 - mean_squared_error: 0.7447 - val_loss: 0.7797 - val_mean_squared_error: 0.7797
# Epoch 255/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7463 - mean_squared_error: 0.7463 - val_loss: 0.7766 - val_mean_squared_error: 0.7766
# Epoch 256/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7461 - mean_squared_error: 0.7461 - val_loss: 0.7828 - val_mean_squared_error: 0.7828
# Epoch 257/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7425 - mean_squared_error: 0.7425 - val_loss: 0.7819 - val_mean_squared_error: 0.7819
# Epoch 258/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7431 - mean_squared_error: 0.7431 - val_loss: 0.7795 - val_mean_squared_error: 0.7795
# Epoch 259/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7448 - mean_squared_error: 0.7448 - val_loss: 0.7864 - val_mean_squared_error: 0.7864
# Epoch 260/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7422 - mean_squared_error: 0.7422 - val_loss: 0.7856 - val_mean_squared_error: 0.7856
# Epoch 261/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7419 - mean_squared_error: 0.7419 - val_loss: 0.7792 - val_mean_squared_error: 0.7792
# Epoch 262/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7437 - mean_squared_error: 0.7437 - val_loss: 0.7804 - val_mean_squared_error: 0.7804
# Epoch 263/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7456 - mean_squared_error: 0.7456 - val_loss: 0.7762 - val_mean_squared_error: 0.7762
# Epoch 264/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7432 - mean_squared_error: 0.7432 - val_loss: 0.7784 - val_mean_squared_error: 0.7784
# Epoch 265/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7453 - mean_squared_error: 0.7453 - val_loss: 0.7835 - val_mean_squared_error: 0.7835
# Epoch 266/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7413 - mean_squared_error: 0.7413 - val_loss: 0.7852 - val_mean_squared_error: 0.7852
# Epoch 267/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7410 - mean_squared_error: 0.7410 - val_loss: 0.7783 - val_mean_squared_error: 0.7783
# Epoch 268/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7432 - mean_squared_error: 0.7432 - val_loss: 0.7831 - val_mean_squared_error: 0.7831
# Epoch 269/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7414 - mean_squared_error: 0.7414 - val_loss: 0.7782 - val_mean_squared_error: 0.7782
# Epoch 270/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7399 - mean_squared_error: 0.7399 - val_loss: 0.7848 - val_mean_squared_error: 0.7848
# Epoch 271/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7425 - mean_squared_error: 0.7425 - val_loss: 0.7820 - val_mean_squared_error: 0.7820
# Epoch 272/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7444 - mean_squared_error: 0.7444 - val_loss: 0.7841 - val_mean_squared_error: 0.7841
# Epoch 273/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7401 - mean_squared_error: 0.7401 - val_loss: 0.7803 - val_mean_squared_error: 0.7803
# Epoch 274/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7428 - mean_squared_error: 0.7428 - val_loss: 0.7801 - val_mean_squared_error: 0.7801
# Epoch 275/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7447 - mean_squared_error: 0.7447 - val_loss: 0.7861 - val_mean_squared_error: 0.7861
# Epoch 276/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7426 - mean_squared_error: 0.7426 - val_loss: 0.7792 - val_mean_squared_error: 0.7792
# Epoch 277/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7436 - mean_squared_error: 0.7436 - val_loss: 0.7797 - val_mean_squared_error: 0.7797
# Epoch 278/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7443 - mean_squared_error: 0.7443 - val_loss: 0.7803 - val_mean_squared_error: 0.7803
# Epoch 279/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7417 - mean_squared_error: 0.7417 - val_loss: 0.7850 - val_mean_squared_error: 0.7850
# Epoch 280/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7448 - mean_squared_error: 0.7448 - val_loss: 0.7772 - val_mean_squared_error: 0.7772
# Epoch 281/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7463 - mean_squared_error: 0.7463 - val_loss: 0.7801 - val_mean_squared_error: 0.7801
# Epoch 282/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7423 - mean_squared_error: 0.7423 - val_loss: 0.7920 - val_mean_squared_error: 0.7920
# Epoch 283/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7463 - mean_squared_error: 0.7463 - val_loss: 0.7826 - val_mean_squared_error: 0.7826
# Epoch 284/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7457 - mean_squared_error: 0.7457 - val_loss: 0.7781 - val_mean_squared_error: 0.7781
# Epoch 285/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7482 - mean_squared_error: 0.7482 - val_loss: 0.7818 - val_mean_squared_error: 0.7818
# Epoch 286/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7457 - mean_squared_error: 0.7457 - val_loss: 0.7780 - val_mean_squared_error: 0.7780
# Epoch 287/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7452 - mean_squared_error: 0.7452 - val_loss: 0.7811 - val_mean_squared_error: 0.7811
# Epoch 288/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7440 - mean_squared_error: 0.7440 - val_loss: 0.7811 - val_mean_squared_error: 0.7811
# Epoch 289/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7437 - mean_squared_error: 0.7437 - val_loss: 0.7805 - val_mean_squared_error: 0.7805
# Epoch 290/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7463 - mean_squared_error: 0.7463 - val_loss: 0.7898 - val_mean_squared_error: 0.7898
# Epoch 291/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7453 - mean_squared_error: 0.7453 - val_loss: 0.7801 - val_mean_squared_error: 0.7801
# Epoch 292/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7411 - mean_squared_error: 0.7411 - val_loss: 0.7816 - val_mean_squared_error: 0.7816
# Epoch 293/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7439 - mean_squared_error: 0.7439 - val_loss: 0.7800 - val_mean_squared_error: 0.7800
# Epoch 294/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7444 - mean_squared_error: 0.7444 - val_loss: 0.7847 - val_mean_squared_error: 0.7847
# Epoch 295/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7465 - mean_squared_error: 0.7465 - val_loss: 0.7869 - val_mean_squared_error: 0.7869
# Epoch 296/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7413 - mean_squared_error: 0.7413 - val_loss: 0.7824 - val_mean_squared_error: 0.7824
# Epoch 297/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7467 - mean_squared_error: 0.7467 - val_loss: 0.7826 - val_mean_squared_error: 0.7826
# Epoch 298/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7435 - mean_squared_error: 0.7435 - val_loss: 0.7795 - val_mean_squared_error: 0.7795
# Epoch 299/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7434 - mean_squared_error: 0.7434 - val_loss: 0.7785 - val_mean_squared_error: 0.7785
# Epoch 300/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7439 - mean_squared_error: 0.7439 - val_loss: 0.7872 - val_mean_squared_error: 0.7872
# Epoch 301/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7471 - mean_squared_error: 0.7471 - val_loss: 0.7778 - val_mean_squared_error: 0.7778
# Epoch 302/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7459 - mean_squared_error: 0.7459 - val_loss: 0.7821 - val_mean_squared_error: 0.7821
# Epoch 303/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7462 - mean_squared_error: 0.7462 - val_loss: 0.7776 - val_mean_squared_error: 0.7776
# Epoch 304/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7414 - mean_squared_error: 0.7414 - val_loss: 0.7809 - val_mean_squared_error: 0.7809
# Epoch 305/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7405 - mean_squared_error: 0.7405 - val_loss: 0.7828 - val_mean_squared_error: 0.7828
# Epoch 306/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7459 - mean_squared_error: 0.7459 - val_loss: 0.7802 - val_mean_squared_error: 0.7802
# Epoch 307/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7424 - mean_squared_error: 0.7424 - val_loss: 0.7832 - val_mean_squared_error: 0.7832
# Epoch 308/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7435 - mean_squared_error: 0.7435 - val_loss: 0.7770 - val_mean_squared_error: 0.7770
# Epoch 309/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7429 - mean_squared_error: 0.7429 - val_loss: 0.7814 - val_mean_squared_error: 0.7814
# Epoch 310/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7422 - mean_squared_error: 0.7422 - val_loss: 0.7847 - val_mean_squared_error: 0.7847
# Epoch 311/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7467 - mean_squared_error: 0.7467 - val_loss: 0.7841 - val_mean_squared_error: 0.7841
# Epoch 312/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7426 - mean_squared_error: 0.7426 - val_loss: 0.7837 - val_mean_squared_error: 0.7837
# Epoch 313/2000
# ...
# Epoch 1297/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7404 - mean_squared_error: 0.7404 - val_loss: 0.7803 - val_mean_squared_error: 0.7803
# Epoch 1298/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7409 - mean_squared_error: 0.7409 - val_loss: 0.7814 - val_mean_squared_error: 0.7814
# Epoch 1299/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7350 - mean_squared_error: 0.7350 - val_loss: 0.7813 - val_mean_squared_error: 0.7813
# Epoch 1300/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7364 - mean_squared_error: 0.7364 - val_loss: 0.7832 - val_mean_squared_error: 0.7832
# Epoch 1301/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7347 - mean_squared_error: 0.7347 - val_loss: 0.7799 - val_mean_squared_error: 0.7799
# Epoch 1302/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7398 - mean_squared_error: 0.7398 - val_loss: 0.7769 - val_mean_squared_error: 0.7769
# Epoch 1303/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7376 - mean_squared_error: 0.7376 - val_loss: 0.7777 - val_mean_squared_error: 0.7777
# Epoch 1304/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7413 - mean_squared_error: 0.7413 - val_loss: 0.7812 - val_mean_squared_error: 0.7812
# Epoch 1305/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7381 - mean_squared_error: 0.7381 - val_loss: 0.7784 - val_mean_squared_error: 0.7784
# Epoch 1306/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7392 - mean_squared_error: 0.7392 - val_loss: 0.7805 - val_mean_squared_error: 0.7805
# Epoch 1307/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7386 - mean_squared_error: 0.7386 - val_loss: 0.7808 - val_mean_squared_error: 0.7808
# Epoch 1308/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7368 - mean_squared_error: 0.7368 - val_loss: 0.7776 - val_mean_squared_error: 0.7776
# Epoch 1309/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7341 - mean_squared_error: 0.7341 - val_loss: 0.7812 - val_mean_squared_error: 0.7812
# Epoch 1310/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7407 - mean_squared_error: 0.7407 - val_loss: 0.7803 - val_mean_squared_error: 0.7803
# Epoch 1311/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7372 - mean_squared_error: 0.7372 - val_loss: 0.7801 - val_mean_squared_error: 0.7801
# Epoch 1312/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7391 - mean_squared_error: 0.7391 - val_loss: 0.7810 - val_mean_squared_error: 0.7810
# Epoch 1313/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7388 - mean_squared_error: 0.7388 - val_loss: 0.7801 - val_mean_squared_error: 0.7801
# Epoch 1314/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7364 - mean_squared_error: 0.7364 - val_loss: 0.7818 - val_mean_squared_error: 0.7818
# Epoch 1315/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7368 - mean_squared_error: 0.7368 - val_loss: 0.7844 - val_mean_squared_error: 0.7844
# Epoch 1316/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7394 - mean_squared_error: 0.7394 - val_loss: 0.7799 - val_mean_squared_error: 0.7799
# Epoch 1317/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7374 - mean_squared_error: 0.7374 - val_loss: 0.7861 - val_mean_squared_error: 0.7861
# Epoch 1318/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.7382 - mean_squared_error: 0.7382 - val_loss: 0.7784 - val_mean_squared_error: 0.7784
# Epoch 1319/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7384 - mean_squared_error: 0.7384 - val_loss: 0.7792 - val_mean_squared_error: 0.7792
# Epoch 1320/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7332 - mean_squared_error: 0.7332 - val_loss: 0.7809 - val_mean_squared_error: 0.7809
# Epoch 1321/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7389 - mean_squared_error: 0.7389 - val_loss: 0.7790 - val_mean_squared_error: 0.7790
# Epoch 1322/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7382 - mean_squared_error: 0.7382 - val_loss: 0.7785 - val_mean_squared_error: 0.7785
# Epoch 1323/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7360 - mean_squared_error: 0.7360 - val_loss: 0.7799 - val_mean_squared_error: 0.7799
# Epoch 1324/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7384 - mean_squared_error: 0.7384 - val_loss: 0.7875 - val_mean_squared_error: 0.7875
# Epoch 1325/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7360 - mean_squared_error: 0.7360 - val_loss: 0.7781 - val_mean_squared_error: 0.7781
# Epoch 1326/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7397 - mean_squared_error: 0.7397 - val_loss: 0.7848 - val_mean_squared_error: 0.7848
# Epoch 1327/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7374 - mean_squared_error: 0.7374 - val_loss: 0.7923 - val_mean_squared_error: 0.7923
# Epoch 1328/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7401 - mean_squared_error: 0.7401 - val_loss: 0.7808 - val_mean_squared_error: 0.7808
# Epoch 1329/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7337 - mean_squared_error: 0.7337 - val_loss: 0.7793 - val_mean_squared_error: 0.7793
# Epoch 1330/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7401 - mean_squared_error: 0.7401 - val_loss: 0.7786 - val_mean_squared_error: 0.7786
# Epoch 1331/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7371 - mean_squared_error: 0.7371 - val_loss: 0.7790 - val_mean_squared_error: 0.7790
# Epoch 1332/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7386 - mean_squared_error: 0.7386 - val_loss: 0.7817 - val_mean_squared_error: 0.7817
# Epoch 1333/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7366 - mean_squared_error: 0.7366 - val_loss: 0.7948 - val_mean_squared_error: 0.7948
# Epoch 1334/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7351 - mean_squared_error: 0.7351 - val_loss: 0.7835 - val_mean_squared_error: 0.7835
# Epoch 1335/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7383 - mean_squared_error: 0.7383 - val_loss: 0.7776 - val_mean_squared_error: 0.7776
# Epoch 1336/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7402 - mean_squared_error: 0.7402 - val_loss: 0.7793 - val_mean_squared_error: 0.7793
# Epoch 1337/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7382 - mean_squared_error: 0.7382 - val_loss: 0.7776 - val_mean_squared_error: 0.7776
# Epoch 1338/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7362 - mean_squared_error: 0.7362 - val_loss: 0.7843 - val_mean_squared_error: 0.7843
# Epoch 1339/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7359 - mean_squared_error: 0.7359 - val_loss: 0.7813 - val_mean_squared_error: 0.7813
# Epoch 1340/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7348 - mean_squared_error: 0.7348 - val_loss: 0.7842 - val_mean_squared_error: 0.7842
# Epoch 1341/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7413 - mean_squared_error: 0.7413 - val_loss: 0.7854 - val_mean_squared_error: 0.7854
# Epoch 1342/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7399 - mean_squared_error: 0.7399 - val_loss: 0.7769 - val_mean_squared_error: 0.7769
# Epoch 1343/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7368 - mean_squared_error: 0.7368 - val_loss: 0.7814 - val_mean_squared_error: 0.7814
# Epoch 1344/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7412 - mean_squared_error: 0.7412 - val_loss: 0.7783 - val_mean_squared_error: 0.7783
# Epoch 1345/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7390 - mean_squared_error: 0.7390 - val_loss: 0.7789 - val_mean_squared_error: 0.7789
# Epoch 1346/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7373 - mean_squared_error: 0.7373 - val_loss: 0.7881 - val_mean_squared_error: 0.7881
# Epoch 1347/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7342 - mean_squared_error: 0.7342 - val_loss: 0.7820 - val_mean_squared_error: 0.7820
# Epoch 1348/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7367 - mean_squared_error: 0.7367 - val_loss: 0.7804 - val_mean_squared_error: 0.7804
# Epoch 1349/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7365 - mean_squared_error: 0.7365 - val_loss: 0.7804 - val_mean_squared_error: 0.7804
# Epoch 1350/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7352 - mean_squared_error: 0.7352 - val_loss: 0.7830 - val_mean_squared_error: 0.7830
# Epoch 1351/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7432 - mean_squared_error: 0.7432 - val_loss: 0.7797 - val_mean_squared_error: 0.7797
# Epoch 1352/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7369 - mean_squared_error: 0.7369 - val_loss: 0.7853 - val_mean_squared_error: 0.7853
# Epoch 1353/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7364 - mean_squared_error: 0.7364 - val_loss: 0.7821 - val_mean_squared_error: 0.7821
# Epoch 1354/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7354 - mean_squared_error: 0.7354 - val_loss: 0.7778 - val_mean_squared_error: 0.7778
# Epoch 1355/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7381 - mean_squared_error: 0.7381 - val_loss: 0.7815 - val_mean_squared_error: 0.7815
# Epoch 1356/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7355 - mean_squared_error: 0.7355 - val_loss: 0.7812 - val_mean_squared_error: 0.7812
# Epoch 1357/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7373 - mean_squared_error: 0.7373 - val_loss: 0.7819 - val_mean_squared_error: 0.7819
# Epoch 1358/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7391 - mean_squared_error: 0.7391 - val_loss: 0.7841 - val_mean_squared_error: 0.7841
# Epoch 1359/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7360 - mean_squared_error: 0.7360 - val_loss: 0.7770 - val_mean_squared_error: 0.7770
# Epoch 1360/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7366 - mean_squared_error: 0.7366 - val_loss: 0.7820 - val_mean_squared_error: 0.7820
# Epoch 1361/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7370 - mean_squared_error: 0.7370 - val_loss: 0.7819 - val_mean_squared_error: 0.7819
# Epoch 1362/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7409 - mean_squared_error: 0.7409 - val_loss: 0.7818 - val_mean_squared_error: 0.7818
# Epoch 1363/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7345 - mean_squared_error: 0.7345 - val_loss: 0.7821 - val_mean_squared_error: 0.7821
# Epoch 1364/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7397 - mean_squared_error: 0.7397 - val_loss: 0.7852 - val_mean_squared_error: 0.7852
# Epoch 1365/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7402 - mean_squared_error: 0.7402 - val_loss: 0.7829 - val_mean_squared_error: 0.7829
# Epoch 1366/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7382 - mean_squared_error: 0.7382 - val_loss: 0.7808 - val_mean_squared_error: 0.7808
# Epoch 1367/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7388 - mean_squared_error: 0.7388 - val_loss: 0.7790 - val_mean_squared_error: 0.7790
# Epoch 1368/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7366 - mean_squared_error: 0.7366 - val_loss: 0.7812 - val_mean_squared_error: 0.7812
# Epoch 1369/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7355 - mean_squared_error: 0.7355 - val_loss: 0.7843 - val_mean_squared_error: 0.7843
# Epoch 1370/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7405 - mean_squared_error: 0.7405 - val_loss: 0.7833 - val_mean_squared_error: 0.7833
# Epoch 1371/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7383 - mean_squared_error: 0.7383 - val_loss: 0.7786 - val_mean_squared_error: 0.7786
# Epoch 1372/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7379 - mean_squared_error: 0.7379 - val_loss: 0.7800 - val_mean_squared_error: 0.7800
# Epoch 1373/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7376 - mean_squared_error: 0.7376 - val_loss: 0.7798 - val_mean_squared_error: 0.7798
# Epoch 1374/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7388 - mean_squared_error: 0.7388 - val_loss: 0.7799 - val_mean_squared_error: 0.7799
# Epoch 1375/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7400 - mean_squared_error: 0.7400 - val_loss: 0.7839 - val_mean_squared_error: 0.7839
# Epoch 1376/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7345 - mean_squared_error: 0.7345 - val_loss: 0.7797 - val_mean_squared_error: 0.7797
# Epoch 1377/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7395 - mean_squared_error: 0.7395 - val_loss: 0.7840 - val_mean_squared_error: 0.7840
# Epoch 1378/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7366 - mean_squared_error: 0.7366 - val_loss: 0.7787 - val_mean_squared_error: 0.7787
# Epoch 1379/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7425 - mean_squared_error: 0.7425 - val_loss: 0.7808 - val_mean_squared_error: 0.7808
# Epoch 1380/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7408 - mean_squared_error: 0.7408 - val_loss: 0.7837 - val_mean_squared_error: 0.7837
# Epoch 1381/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7384 - mean_squared_error: 0.7384 - val_loss: 0.7756 - val_mean_squared_error: 0.7756
# Epoch 1382/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7392 - mean_squared_error: 0.7392 - val_loss: 0.7820 - val_mean_squared_error: 0.7820
# Epoch 1383/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7410 - mean_squared_error: 0.7410 - val_loss: 0.7795 - val_mean_squared_error: 0.7795
# Epoch 1384/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7376 - mean_squared_error: 0.7376 - val_loss: 0.7960 - val_mean_squared_error: 0.7960
# Epoch 1385/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7370 - mean_squared_error: 0.7370 - val_loss: 0.7813 - val_mean_squared_error: 0.7813
# Epoch 1386/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7349 - mean_squared_error: 0.7349 - val_loss: 0.7776 - val_mean_squared_error: 0.7776
# Epoch 1387/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7380 - mean_squared_error: 0.7380 - val_loss: 0.7860 - val_mean_squared_error: 0.7860
# Epoch 1388/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7403 - mean_squared_error: 0.7403 - val_loss: 0.7801 - val_mean_squared_error: 0.7801
# Epoch 1389/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7395 - mean_squared_error: 0.7395 - val_loss: 0.7799 - val_mean_squared_error: 0.7799
# Epoch 1390/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.7385 - mean_squared_error: 0.7385 - val_loss: 0.7860 - val_mean_squared_error: 0.7860
# Epoch 1391/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7386 - mean_squared_error: 0.7386 - val_loss: 0.7786 - val_mean_squared_error: 0.7786
# Epoch 1392/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7335 - mean_squared_error: 0.7335 - val_loss: 0.7797 - val_mean_squared_error: 0.7797
# Epoch 1393/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7365 - mean_squared_error: 0.7365 - val_loss: 0.7880 - val_mean_squared_error: 0.7880
# Epoch 1394/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.7403 - mean_squared_error: 0.7403 - val_loss: 0.7778 - val_mean_squared_error: 0.7778
# Epoch 1395/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.7370 - mean_squared_error: 0.7370 - val_loss: 0.7797 - val_mean_squared_error: 0.7797
# Epoch 1396/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.7382 - mean_squared_error: 0.7382 - val_loss: 0.7801 - val_mean_squared_error: 0.7801
# Epoch 1397/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7386 - mean_squared_error: 0.7386 - val_loss: 0.7821 - val_mean_squared_error: 0.7821
# Epoch 1398/2000
# 1890/1890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7366 - mean_squared_error: 0.7366 - val_loss: 0.7839 - val_mean_squared_error: 0.7839
# Epoch 1399/2000
# 1872/1890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7363 - mean_squared_error: 0.7363

# %%
from google.colab import drive
drive.mount('/content/drive')
