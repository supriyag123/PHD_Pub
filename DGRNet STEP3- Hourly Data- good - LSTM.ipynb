# %% [markdown]
# <a href="https://colab.research.google.com/github/supriyag123/PHD_Pub/blob/main/DGRNet%20STEP3-%20Hourly%20Data-%20good%20-%20LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import math
import plotly.graph_objects as go
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, RepeatVector, TimeDistributed, Input
from keras.models import Model
from keras import backend as K
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import EarlyStopping
import keras.backend as K
from keras.callbacks import Callback
import plotly
import plotly.express as px # for data visualization
import seaborn as sns

generator_multiply = 1 #each input record will generate 100 random vectors from the latent space, given the mu and sigma generated by the encoder

#from keras.utils import plot_model
#import matplotlib.pyplot as plt

#window1 = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences_WINDOW-500.npy')
#window2 = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences_WINDOW-1000.npy')
#window = np.concatenate((window1, window2), axis=0)
#train_data = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences-TRAIN.npy')
#test_data = np.load(r'/content/drive/MyDrive/PHD/2021/multivariate_long_sequences-TEST.npy')



train_data = np.load(r'/content/drive/MyDrive/PHD/2024/multivariate_long_sequences-TRAIN_hourly.npy') #------for Hourly data
index = 500
#We missed i=500 from processing the iosw. So here we are dropping row with index =500
train_data= np.delete(train_data, index, axis=0)


#test_data = np.load(r'/content/drive/MyDrive/PHD/2024/multivariate_long_sequences-TEST_hourly.npy')
#all_data = np.concatenate((train_data,test_data),axis=0)
window_label = np.load(r'/content/drive/MyDrive/PHD/2024/multivariate_long_sequences_WINDOW-TRAIN_hourly.npy')
n_seq = train_data.shape[0]
window_size = train_data.shape[1]
n_features = train_data.shape[2]


#---------------------------VAE ------------------------------------------
#from sklearn.model_selection import train_test_split
#x_train, x_test, y_train, y_test = train_test_split(train_data, window_label, test_size = 0.2, random_state = 42)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

encoder = keras.models.load_model(r'/content/drive/MyDrive/PHD/2024/VAE_SIMULATION/vae-encoder-saved-hourly-latent10-dim128-latest.model')
decoder = keras.models.load_model(r'/content/drive/MyDrive/PHD/2024/VAE_SIMULATION/vae-decoder-saved-hourly-latent10-dim128-latest.model')

X_train_encoded = encoder.predict(train_data)
mu, logvar, z = X_train_encoded
sigma = tf.exp(0.5 * logvar)
batch = tf.shape(mu)[0]  #number of recors / batchs
dim = tf.shape(mu)[1] #Ndimension of latent variable
store = list()
storetemp = list()


#For each batch, iterate, get the generator_multipy number of latent vectors with same window_size.
#For each z, concatenate z_mean, so it will become 100 dimensional vector

for i in range(0,batch):
  all_Z_i = tf.random.normal(shape=(generator_multiply,dim), mean = mu[i,:], stddev=sigma[i,:]) #all randorm vectors for this record i
  X_train_decoded = decoder.predict(all_Z_i)
  X_train_decoded = X_train_decoded.reshape((X_train_decoded.shape[0],window_size*n_features))
  a = np.arange(generator_multiply)
  a.fill(window_label[i])
  c=np.concatenate(((X_train_decoded,a[:,None])),axis=1)
  store.append(c)

results1=np.concatenate(store,axis=0)
results1=np.load(r'/content/drive/MyDrive/PHD/2024/labelled_subsquence_data_hourly.npy')
#results1=np.load(r'/content/drive/MyDrive/PHD/2024/labelled_subsquence_data_hourly_multuply_2.npy')
#np.save(r'/content/drive/MyDrive/PHD/2024/labelled_subsquence_data_hourly_multuply_2',results1)
np.save(r'/content/drive/MyDrive/PHD/2024/labelled_subsquence_data_hourly',results1)


#Regression fitting
x=results1[:,:-1]
y=results1[:,window_size*n_features]


from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

#----- get a test set from this data, to avoid further wrangling----------------
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state = 42)


maxval = x.shape[0]
count_train = int(math.ceil(0.9*maxval))
x_train = x[:count_train]
x_test = x[count_train:]

y_train = y[:count_train]
y_test = y[count_train:]


from sklearn.ensemble import IsolationForest
iso = IsolationForest(contamination=0.4)
yhat = iso.fit_predict(x_train)
# select all rows that are not outliers
mask = yhat != -1
x_train, y_train = x_train[mask, :], y_train[mask]

x_train = x_train.reshape((x_train.shape[0], window_size, n_features))  #DONT RUN IF MLP
x_test = x_test.reshape((x_test.shape[0], window_size, n_features))    #DONT RUN IF MLP


from sklearn.preprocessing import StandardScaler
from keras.layers import Bidirectional
from tensorflow.keras.activations import selu

transformer = StandardScaler()

y_train_transformed = transformer.fit_transform(y_train.reshape(-1,1)).flatten()
y_test_transformed = transformer.fit_transform(y_test.reshape(-1,1)).flatten()


from keras.layers import LeakyReLU

a = x_train.shape[1]
b= x_train.shape[2]

model = Sequential()
model.add(LSTM(64, input_shape=(a,b),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32))
model.add(Dropout(0.2))
#model.add(Dense(units = 1024))
#model.add(LeakyReLU(alpha=0.1))
#model.add(Dense(units = 512))
#model.add(LeakyReLU(alpha=0.1))
#model.add(Dense(units = 512))
#model.add(LeakyReLU(alpha=0.1))
#model.add(Dense(units = 256))
#model.add(LeakyReLU(alpha=0.1))

model.add(Dense(units = 32))
model.add(LeakyReLU(alpha=0.1))
#model.add(Dense(units = 16))
#model.add(LeakyReLU(alpha=0.01))
#model.add(Dense(units = 8))
#model.add(LeakyReLU(alpha=0.01))
#model.add(Dense(units = 4))
#model.add(LeakyReLU(alpha=0.01))
model.add(Dense(units = 1))

#sgd = tf.keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
optimizr = keras.optimizers.Adam(learning_rate=0.0001,clipnorm=1)
model.compile(loss='mean_squared_error', optimizer= optimizr, metrics=['mean_squared_error'])
#model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])


#reduce_lr = tf.keras.callbacks.LearningRateScheduler(lambda x: 1e-3 * 0.90 ** x)
es = keras.callbacks.EarlyStopping(patience=30, verbose=1, min_delta=0.00001, monitor='loss', mode='auto', restore_best_weights=True)
n_epochs = 500
#model.fit(x_train, y_train,epochs=5, batch_size=50, verbose=True)

#y_pred = model.predict(x_test)

#transform

#x_val = x_train[10001:13000]
#y_val = y_train_transformed[10001:13000]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train_transformed, test_size = 0.1, random_state = 42)


history=model.fit( x_train,y_train,
                 epochs=n_epochs,
                 batch_size=50,
                   #validation_data=(x_val,y_val),
                   validation_split=0.1,
                 callbacks=[es])

y_train_pred = model.predict(x_train)
y_train_pred = transformer.inverse_transform(y_train_pred)

y_pred = model.predict(x_test)
y_pred = transformer.inverse_transform(y_pred)

y_train = transformer.inverse_transform(y_train.reshape(-1,1)).flatten()
y_test = transformer.inverse_transform(y_test.reshape(-1,1)).flatten()



score_train= r2_score(y_train,y_train_pred)
print("r2 score is ==",score_train)

score= r2_score(y_test,y_pred)
print("r2 score is ==",score)


#plt.scatter(y_test,y_pred);
#plt.xlabel('Actual');
#plt.ylabel('Predicted');
plt.plot(y_train[0:100], color = 'red', label = 'Real data')
plt.plot(y_train_pred[0:100], color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

#plt.scatter(y_test,y_pred);
#plt.xlabel('Actual');
#plt.ylabel('Predicted');
plt.plot(y_test[100:150], color = 'red', label = 'Real data')
plt.plot(y_pred[100:150], color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()




np.savetxt(r'/content/drive/MyDrive/PHD/2024/MLPOutput/preduber_2.csv',y_pred)
np.savetxt(r'/content/drive/MyDrive/PHD/2024/MLPOutput/realuber_2.csv',y_test)
print("MAE is==",mean_absolute_error(y_test,y_pred))


#--------------------------------------Random Forest-------------------------------------------------------


###### Random forrest ergression
from sklearn.ensemble import RandomForestRegressor
 # create regressor object
regressor = RandomForestRegressor(n_estimators = 1000, random_state = 0)
# fit the regressor with x and y data
regressor.fit(x_train[0:10000],y_train_transformed[0:10000])


y_train_pred = regressor.predict(x_train[0:10000])
y_train_pred = y_train_pred.reshape(-1,1)
y_train_pred = transformer.inverse_transform(y_train_pred)

y_pred = regressor.predict(x_test[0:1000])
y_pred = y_pred.reshape(-1,1)
y_pred = transformer.inverse_transform(y_pred)


score_train= r2_score(y_train[0:10000],y_train_pred)
print("r2 score is ==",score_train)

score= r2_score(y_test[0:1000],y_pred)
print("r2 score is ==",score)


#plt.scatter(y_test,y_pred);
#plt.xlabel('Actual');
#plt.ylabel('Predicted');
plt.plot(y_train[0:1000], color = 'red', label = 'Real data')
plt.plot(y_train_pred[0:1000], color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

#plt.scatter(y_test,y_pred);
#plt.xlabel('Actual');
#plt.ylabel('Predicted');
plt.plot(y_test[0:1000], color = 'red', label = 'Real data')
plt.plot(y_pred[0:1000], color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()


sns.regplot(x=y_test[0:10],y=y_pred,ci=None,color ='red');
# Out:
# Epoch 1/500
# 543/543 [==============================] - 15s 16ms/step - loss: 0.9882 - mean_squared_error: 0.9882 - val_loss: 0.9871 - val_mean_squared_error: 0.9871
# Epoch 2/500
# 543/543 [==============================] - 6s 11ms/step - loss: 0.9597 - mean_squared_error: 0.9597 - val_loss: 0.9564 - val_mean_squared_error: 0.9564
# Epoch 3/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.9396 - mean_squared_error: 0.9396 - val_loss: 0.9295 - val_mean_squared_error: 0.9295
# Epoch 4/500
# 543/543 [==============================] - 6s 11ms/step - loss: 0.9123 - mean_squared_error: 0.9123 - val_loss: 0.9174 - val_mean_squared_error: 0.9174
# Epoch 5/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8911 - mean_squared_error: 0.8911 - val_loss: 0.8817 - val_mean_squared_error: 0.8817
# Epoch 6/500
# 543/543 [==============================] - 6s 11ms/step - loss: 0.8779 - mean_squared_error: 0.8779 - val_loss: 0.8757 - val_mean_squared_error: 0.8757
# Epoch 7/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8748 - mean_squared_error: 0.8748 - val_loss: 0.8769 - val_mean_squared_error: 0.8769
# Epoch 8/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8735 - mean_squared_error: 0.8735 - val_loss: 0.8946 - val_mean_squared_error: 0.8946
# Epoch 9/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8731 - mean_squared_error: 0.8731 - val_loss: 0.8728 - val_mean_squared_error: 0.8728
# Epoch 10/500
# 543/543 [==============================] - 12s 22ms/step - loss: 0.8722 - mean_squared_error: 0.8722 - val_loss: 0.8779 - val_mean_squared_error: 0.8779
# Epoch 11/500
# 543/543 [==============================] - 7s 13ms/step - loss: 0.8730 - mean_squared_error: 0.8730 - val_loss: 0.8806 - val_mean_squared_error: 0.8806
# Epoch 12/500
# 543/543 [==============================] - 7s 12ms/step - loss: 0.8705 - mean_squared_error: 0.8705 - val_loss: 0.8826 - val_mean_squared_error: 0.8826
# Epoch 13/500
# 543/543 [==============================] - 7s 13ms/step - loss: 0.8707 - mean_squared_error: 0.8707 - val_loss: 0.8793 - val_mean_squared_error: 0.8793
# Epoch 14/500
# 543/543 [==============================] - 7s 12ms/step - loss: 0.8720 - mean_squared_error: 0.8720 - val_loss: 0.8770 - val_mean_squared_error: 0.8770
# Epoch 15/500
# 543/543 [==============================] - 7s 13ms/step - loss: 0.8694 - mean_squared_error: 0.8694 - val_loss: 0.8789 - val_mean_squared_error: 0.8789
# Epoch 16/500
# 543/543 [==============================] - 7s 12ms/step - loss: 0.8702 - mean_squared_error: 0.8702 - val_loss: 0.8738 - val_mean_squared_error: 0.8738
# Epoch 17/500
# 543/543 [==============================] - 7s 13ms/step - loss: 0.8697 - mean_squared_error: 0.8697 - val_loss: 0.8832 - val_mean_squared_error: 0.8832
# Epoch 18/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8680 - mean_squared_error: 0.8680 - val_loss: 0.8722 - val_mean_squared_error: 0.8722
# Epoch 19/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8695 - mean_squared_error: 0.8695 - val_loss: 0.8697 - val_mean_squared_error: 0.8697
# Epoch 20/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8675 - mean_squared_error: 0.8675 - val_loss: 0.8704 - val_mean_squared_error: 0.8704
# Epoch 21/500
# 543/543 [==============================] - 8s 14ms/step - loss: 0.8689 - mean_squared_error: 0.8689 - val_loss: 0.8734 - val_mean_squared_error: 0.8734
# Epoch 22/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8685 - mean_squared_error: 0.8685 - val_loss: 0.8793 - val_mean_squared_error: 0.8793
# Epoch 23/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8684 - mean_squared_error: 0.8684 - val_loss: 0.8725 - val_mean_squared_error: 0.8725
# Epoch 24/500
# 543/543 [==============================] - 6s 11ms/step - loss: 0.8673 - mean_squared_error: 0.8673 - val_loss: 0.8763 - val_mean_squared_error: 0.8763
# Epoch 25/500
# 543/543 [==============================] - 8s 14ms/step - loss: 0.8673 - mean_squared_error: 0.8673 - val_loss: 0.8691 - val_mean_squared_error: 0.8691
# Epoch 26/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8685 - mean_squared_error: 0.8685 - val_loss: 0.8752 - val_mean_squared_error: 0.8752
# Epoch 27/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8665 - mean_squared_error: 0.8665 - val_loss: 0.8808 - val_mean_squared_error: 0.8808
# Epoch 28/500
# 543/543 [==============================] - 6s 11ms/step - loss: 0.8652 - mean_squared_error: 0.8652 - val_loss: 0.8699 - val_mean_squared_error: 0.8699
# Epoch 29/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8667 - mean_squared_error: 0.8667 - val_loss: 0.8682 - val_mean_squared_error: 0.8682
# Epoch 30/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8661 - mean_squared_error: 0.8661 - val_loss: 0.8771 - val_mean_squared_error: 0.8771
# Epoch 31/500
# 543/543 [==============================] - 8s 14ms/step - loss: 0.8658 - mean_squared_error: 0.8658 - val_loss: 0.8747 - val_mean_squared_error: 0.8747
# Epoch 32/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8670 - mean_squared_error: 0.8670 - val_loss: 0.8916 - val_mean_squared_error: 0.8916
# Epoch 33/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8646 - mean_squared_error: 0.8646 - val_loss: 0.8727 - val_mean_squared_error: 0.8727
# Epoch 34/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8651 - mean_squared_error: 0.8651 - val_loss: 0.8682 - val_mean_squared_error: 0.8682
# Epoch 35/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8643 - mean_squared_error: 0.8643 - val_loss: 0.8721 - val_mean_squared_error: 0.8721
# Epoch 36/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8650 - mean_squared_error: 0.8650 - val_loss: 0.8702 - val_mean_squared_error: 0.8702
# Epoch 37/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8641 - mean_squared_error: 0.8641 - val_loss: 0.8717 - val_mean_squared_error: 0.8717
# Epoch 38/500
# 543/543 [==============================] - 7s 12ms/step - loss: 0.8646 - mean_squared_error: 0.8646 - val_loss: 0.8718 - val_mean_squared_error: 0.8718
# Epoch 39/500
# 543/543 [==============================] - 8s 15ms/step - loss: 0.8633 - mean_squared_error: 0.8633 - val_loss: 0.8760 - val_mean_squared_error: 0.8760
# Epoch 40/500
# 543/543 [==============================] - 7s 12ms/step - loss: 0.8646 - mean_squared_error: 0.8646 - val_loss: 0.8710 - val_mean_squared_error: 0.8710
# Epoch 41/500
# 543/543 [==============================] - 9s 16ms/step - loss: 0.8669 - mean_squared_error: 0.8669 - val_loss: 0.8774 - val_mean_squared_error: 0.8774
# Epoch 42/500
# 543/543 [==============================] - 7s 13ms/step - loss: 0.8660 - mean_squared_error: 0.8660 - val_loss: 0.8730 - val_mean_squared_error: 0.8730
# Epoch 43/500
# 543/543 [==============================] - 8s 15ms/step - loss: 0.8654 - mean_squared_error: 0.8654 - val_loss: 0.8709 - val_mean_squared_error: 0.8709
# Epoch 44/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8661 - mean_squared_error: 0.8661 - val_loss: 0.8721 - val_mean_squared_error: 0.8721
# Epoch 45/500
# 543/543 [==============================] - 8s 15ms/step - loss: 0.8644 - mean_squared_error: 0.8644 - val_loss: 0.8726 - val_mean_squared_error: 0.8726
# Epoch 46/500
# 543/543 [==============================] - 8s 15ms/step - loss: 0.8635 - mean_squared_error: 0.8635 - val_loss: 0.8729 - val_mean_squared_error: 0.8729
# Epoch 47/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8625 - mean_squared_error: 0.8625 - val_loss: 0.8686 - val_mean_squared_error: 0.8686
# Epoch 48/500
# 543/543 [==============================] - 8s 15ms/step - loss: 0.8648 - mean_squared_error: 0.8648 - val_loss: 0.8682 - val_mean_squared_error: 0.8682
# Epoch 49/500
# 543/543 [==============================] - 7s 12ms/step - loss: 0.8643 - mean_squared_error: 0.8643 - val_loss: 0.8703 - val_mean_squared_error: 0.8703
# Epoch 50/500
# 543/543 [==============================] - 8s 15ms/step - loss: 0.8654 - mean_squared_error: 0.8654 - val_loss: 0.8690 - val_mean_squared_error: 0.8690
# Epoch 51/500
# 543/543 [==============================] - 7s 13ms/step - loss: 0.8666 - mean_squared_error: 0.8666 - val_loss: 0.8744 - val_mean_squared_error: 0.8744
# Epoch 52/500
# 543/543 [==============================] - 8s 15ms/step - loss: 0.8646 - mean_squared_error: 0.8646 - val_loss: 0.8743 - val_mean_squared_error: 0.8743
# Epoch 53/500
# 543/543 [==============================] - 7s 13ms/step - loss: 0.8634 - mean_squared_error: 0.8634 - val_loss: 0.8723 - val_mean_squared_error: 0.8723
# Epoch 54/500
# 543/543 [==============================] - 8s 15ms/step - loss: 0.8642 - mean_squared_error: 0.8642 - val_loss: 0.8702 - val_mean_squared_error: 0.8702
# Epoch 55/500
# 543/543 [==============================] - 7s 12ms/step - loss: 0.8633 - mean_squared_error: 0.8633 - val_loss: 0.8813 - val_mean_squared_error: 0.8813
# Epoch 56/500
# 543/543 [==============================] - 8s 15ms/step - loss: 0.8636 - mean_squared_error: 0.8636 - val_loss: 0.8752 - val_mean_squared_error: 0.8752
# Epoch 57/500
# 543/543 [==============================] - 7s 12ms/step - loss: 0.8665 - mean_squared_error: 0.8665 - val_loss: 0.8770 - val_mean_squared_error: 0.8770
# Epoch 58/500
# 543/543 [==============================] - 8s 14ms/step - loss: 0.8640 - mean_squared_error: 0.8640 - val_loss: 0.8698 - val_mean_squared_error: 0.8698
# Epoch 59/500
# 543/543 [==============================] - 7s 13ms/step - loss: 0.8645 - mean_squared_error: 0.8645 - val_loss: 0.8702 - val_mean_squared_error: 0.8702
# Epoch 60/500
# 543/543 [==============================] - 8s 14ms/step - loss: 0.8648 - mean_squared_error: 0.8648 - val_loss: 0.8750 - val_mean_squared_error: 0.8750
# Epoch 61/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8642 - mean_squared_error: 0.8642 - val_loss: 0.8700 - val_mean_squared_error: 0.8700
# Epoch 62/500
# 543/543 [==============================] - 8s 14ms/step - loss: 0.8647 - mean_squared_error: 0.8647 - val_loss: 0.8746 - val_mean_squared_error: 0.8746
# Epoch 63/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8650 - mean_squared_error: 0.8650 - val_loss: 0.8693 - val_mean_squared_error: 0.8693
# Epoch 64/500
# 543/543 [==============================] - 8s 14ms/step - loss: 0.8635 - mean_squared_error: 0.8635 - val_loss: 0.8708 - val_mean_squared_error: 0.8708
# Epoch 65/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8650 - mean_squared_error: 0.8650 - val_loss: 0.8721 - val_mean_squared_error: 0.8721
# Epoch 66/500
# 543/543 [==============================] - 8s 14ms/step - loss: 0.8628 - mean_squared_error: 0.8628 - val_loss: 0.8810 - val_mean_squared_error: 0.8810
# Epoch 67/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8626 - mean_squared_error: 0.8626 - val_loss: 0.8811 - val_mean_squared_error: 0.8811
# Epoch 68/500
# 543/543 [==============================] - 7s 14ms/step - loss: 0.8648 - mean_squared_error: 0.8648 - val_loss: 0.8723 - val_mean_squared_error: 0.8723
# Epoch 69/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8657 - mean_squared_error: 0.8657 - val_loss: 0.8725 - val_mean_squared_error: 0.8725
# Epoch 70/500
# 543/543 [==============================] - 8s 14ms/step - loss: 0.8645 - mean_squared_error: 0.8645 - val_loss: 0.8741 - val_mean_squared_error: 0.8741
# Epoch 71/500
# 543/543 [==============================] - 6s 12ms/step - loss: 0.8642 - mean_squared_error: 0.8642 - val_loss: 0.8840 - val_mean_squared_error: 0.8840
# Epoch 72/500
# 543/543 [==============================] - 8s 14ms/step - loss: 0.8645 - mean_squared_error: 0.8645 - val_loss: 0.8732 - val_mean_squared_error: 0.8732
# Epoch 73/500
# 543/543 [==============================] - 7s 13ms/step - loss: 0.8641 - mean_squared_error: 0.8641 - val_loss: 0.8791 - val_mean_squared_error: 0.8791
# Epoch 74/500
# 543/543 [==============================] - 8s 15ms/step - loss: 0.8658 - mean_squared_error: 0.8658 - val_loss: 0.8721 - val_mean_squared_error: 0.8721
# Epoch 75/500
# 543/543 [==============================] - 7s 12ms/step - loss: 0.8669 - mean_squared_error: 0.8669 - val_loss: 0.8758 - val_mean_squared_error: 0.8758
# Epoch 76/500
# 543/543 [==============================] - 8s 15ms/step - loss: 0.8658 - mean_squared_error: 0.8658 - val_loss: 0.8770 - val_mean_squared_error: 0.8770
# Epoch 77/500
# 540/543 [============================>.] - ETA: 0s - loss: 0.8653 - mean_squared_error: 0.8653Restoring model weights from the end of the best epoch: 47.
# 543/543 [==============================] - 7s 13ms/step - loss: 0.8655 - mean_squared_error: 0.8655 - val_loss: 0.8705 - val_mean_squared_error: 0.8705
# Epoch 77: early stopping
# 943/943 [==============================] - 6s 5ms/step
# 105/105 [==============================] - 1s 7ms/step
# r2 score is == 0.14008288893029563
# r2 score is == 0.1487990727837143

# %%
from google.colab import drive
drive.mount('/content/drive')
